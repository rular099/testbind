# %%
from zbexample import utils
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x=np.random.rand(1000)+np.linspace(1,1000,1000)/200
x2=utils.detrend(x)

# %%
fig=plt.figure()
ax=fig.add_subplot(211)
ax.plot(x)
ax=fig.add_subplot(212)
ax.plot(x2)
# Out:
# <img src="data:image/png;base64,..." width="640">
